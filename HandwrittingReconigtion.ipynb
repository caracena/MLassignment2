# %%
from Main import Main
import pandas as pd
# %matplotlib inline

# %% [markdown]
# # Creating the Main Class

# %%
m = Main()

# %% [markdown]
# ## Applying PCA to get the reduced and compressed Matrix

# %%
X_reduced_90,X_reconstructed_90 = m.PCA(0.9)
X_reduced_50,X_reconstructed_50 = m.PCA(0.5)
X_reduced_10,X_reconstructed_10 = m.PCA(0.1)

# %% [markdown]
# ## Numbers Representation Keeping 90% of the Variance

# %%
m.predictor.displayNumbers(pd.DataFrame(X_reconstructed_90),m.y_labels)

# %% [markdown]
# ## Numbers Representation Keeping 50% of the Variance

# %%
m.predictor.displayNumbers(pd.DataFrame(X_reconstructed_50),m.y_labels)

# %% [markdown]
# ## Numbers Representation Keeping 10% of the Variance

# %%
m.predictor.displayNumbers(pd.DataFrame(X_reconstructed_10),m.y_labels)
